# %%
pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using legacy 'setup.py install' for apyori, since package 'wheel' is not installed.
# Installing collected packages: apyori
#   Running setup.py install for apyori: started
#   Running setup.py install for apyori: finished with status 'done'
# Successfully installed apyori-1.1.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\sushant wabale\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori

# %%
df = pd.read_csv("Stationery.csv")

# %%
df.head()
# Out:
#    ID    Name     Item1      Item2      Item3  Item4  Bill
# 0   1  Tushar    Pencil     Eraser   Sharpner    NaN    20
# 1   2  Ramesh       Pen      Pages      Files    Gum    65
# 2   3  Pankaj    Eraser    Perfume  Chocolate    NaN    40
# 3   4  Kartik     Pages      Files    Stapler  Scale   110
# 4   5  Ganesh  Biscuits  Chocolate        NaN    NaN    15

# %%
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Item1     0
# Item2     2
# Item3     6
# Item4    16
# Bill      0
# dtype: int64

# %%
df1 = df[['Item1','Item2','Item3','Item4']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      23 non-null     int64
#  1   Name    23 non-null     object
#  2   Item1   23 non-null     object
#  3   Item2   21 non-null     object
#  4   Item3   17 non-null     object
#  5   Item4   7 non-null      object
#  6   Bill    23 non-null     int64
# dtypes: int64(2), object(5)
# memory usage: 1.4+ KB

# %%
df1.head()
# Out:
#       Item1      Item2      Item3  Item4
# 0    Pencil     Eraser   Sharpner    NaN
# 1       Pen      Pages      Files    Gum
# 2    Eraser    Perfume  Chocolate    NaN
# 3     Pages      Files    Stapler  Scale
# 4  Biscuits  Chocolate        NaN    NaN

# %%
records = []
for i in range(23):
    records.append([str(df1.values[i, j]) for j in range(0, 4)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print("There are {} Relation derived.".format(len(association_results)))
# Out:
# There are 58 Relation derived.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'Eraser', 'Sharpner'})
# frozenset({'Stapler', 'Files'})
# frozenset({'Scale', 'Gum'})
# frozenset({'Sheets', 'Gum'})
# frozenset({'Pages', 'Stapler'})
# frozenset({'Pencil', 'Sharpner'})
# frozenset({'Scale', 'Stapler'})
# frozenset({'Biscuits', 'Chocolate', 'Pencil'})
# frozenset({'Biscuits', 'Chocolate', 'Scale'})
# frozenset({'Biscuits', 'Chocolate', 'nan'})
# frozenset({'Compass', 'Chocolate', 'Files'})
# frozenset({'Eraser', 'Chocolate', 'Perfume'})
# frozenset({'Compass', 'Pages', 'Files'})
# frozenset({'Compass', 'Pen', 'Files'})
# frozenset({'Compass', 'Scale', 'Gum'})
# frozenset({'Compass', 'Sheets', 'Gum'})
# frozenset({'Compass', 'Scale', 'Sheets'})
# frozenset({'Eraser', 'Pencil', 'Pen'})
# frozenset({'Eraser', 'Pen', 'Sharpner'})
# frozenset({'Eraser', 'Pencil', 'Sharpner'})
# frozenset({'Eraser', 'nan', 'Perfume'})
# frozenset({'Eraser', 'Sharpner', 'nan'})
# frozenset({'Pages', 'Files', 'Gum'})
# frozenset({'Pen', 'Files', 'Gum'})
# frozenset({'Scale', 'Files', 'Gum'})
# frozenset({'nan', 'Files', 'Gum'})
# frozenset({'Pages', 'Pen', 'Files'})
# frozenset({'Pages', 'Pencil', 'Files'})
# frozenset({'Pages', 'Scale', 'Files'})
# frozenset({'Pages', 'Stapler', 'Files'})
# frozenset({'Scale', 'Stapler', 'Files'})
# frozenset({'Pages', 'Pen', 'Gum'})
# frozenset({'Scale', 'Sheets', 'Gum'})
# frozenset({'Scale', 'nan', 'Gum'})
# frozenset({'Pages', 'Notebook', 'Perfume'})
# frozenset({'Pen', 'Notebook', 'nan'})
# frozenset({'Notebook', 'Sheets', 'nan'})
# frozenset({'Pages', 'nan', 'Perfume'})
# frozenset({'Pages', 'Stapler', 'Scale'})
# frozenset({'Scale', 'Pencil', 'Pen'})
# frozenset({'Pencil', 'Pen', 'Sharpner'})
# frozenset({'Pencil', 'Sharpner', 'nan'})
# frozenset({'Biscuits', 'Chocolate', 'Pencil', 'nan'})
# frozenset({'Biscuits', 'Chocolate', 'Scale', 'nan'})
# frozenset({'Compass', 'Chocolate', 'Pen', 'Files'})
# frozenset({'Eraser', 'Chocolate', 'nan', 'Perfume'})
# frozenset({'Chocolate', 'Pen', 'Notebook', 'nan'})
# frozenset({'Compass', 'nan', 'Pages', 'Files'})
# frozenset({'Compass', 'Scale', 'Sheets', 'Gum'})
# frozenset({'Eraser', 'Pencil', 'Pen', 'Sharpner'})
# frozenset({'Eraser', 'Pencil', 'Sharpner', 'nan'})
# frozenset({'Pages', 'Pen', 'Files', 'Gum'})
# frozenset({'Scale', 'nan', 'Files', 'Gum'})
# frozenset({'Pages', 'Pencil', 'Pen', 'Files'})
# frozenset({'Pages', 'Stapler', 'Scale', 'Files'})
# frozenset({'Pages', 'Notebook', 'nan', 'Perfume'})
# frozenset({'Pencil', 'Pen', 'Notebook', 'nan'})
# frozenset({'Scale', 'Pencil', 'Pen', 'nan'})

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Eraser -> Sharpner
# Support: 0.13043478260869565
# Confidence: 0.75
# Lift: 5.75
# =====================================
# Rule: Stapler -> Files
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Scale -> Gum
# Support: 0.08695652173913043
# Confidence: 0.6666666666666666
# Lift: 3.0666666666666664
# =====================================
# Rule: Sheets -> Gum
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Pages -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pencil -> Sharpner
# Support: 0.13043478260869565
# Confidence: 0.42857142857142855
# Lift: 3.2857142857142856
# =====================================
# =====================================
# Rule: Scale -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Scale -> nan
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pages -> Notebook
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pen -> Notebook
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 3.8333333333333335
# =====================================
# Rule: Notebook -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pages -> nan
# Support: 0.043478260869565216
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Pages -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Scale -> Pencil
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Pencil -> Pen
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: Pencil -> Sharpner
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Biscuits -> Chocolate
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Biscuits -> Chocolate
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Compass -> Chocolate
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Eraser -> Chocolate
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Chocolate -> Pen
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Compass -> nan
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Compass -> Scale
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Eraser -> Pencil
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Eraser -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pages -> Pen
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Scale -> nan
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Pages -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pages -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pages -> Notebook
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pencil -> Pen
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 7.666666666666667
# =====================================
# Rule: Scale -> Pencil
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 5.75
# =====================================
